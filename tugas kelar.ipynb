# %%
import sqlite3
import pandas as pd

# %% [markdown]
# # Connect sqlite3 to python

# %%
connection = sqlite3.connect('data.sqlite')

# %% [markdown]
# # Operasi Insert

# %%
result = connection.cursor()
command = "INSERT INTO AGENTS VALUES ('A013', 'Achmad Malik', 'Indonesia', '0.27', '021-14045', '')"
result.execute(command)

# %% [markdown]
# # Operasi Select

# %%
command = "select * from agents"
result.execute(command)
results = result.fetchall()
cols = [column[0] for column in result.description]
results_data= pd.DataFrame.from_records(results, columns = cols)

results_data
# Out:
#    AGENT_CODE    AGENT_NAME WORKING_AREA COMMISSION      PHONE_NO COUNTRY
# 0        A001      Subbarao    Bangalore       0.14  077-12346674
# 1        A002        Mukesh       Mumbai       0.11  029-12358964
# 2        A003         Alex        London       0.13  075-12458969
# 3        A004          Ivan      Torento       0.15  008-22544166
# 4        A005      Anderson      Brisban       0.13  045-21447739
# 5        A006         McDen       London       0.15  078-22255588
# 6        A007    Ramasundar    Bangalore       0.15  077-25814763
# 7        A008        Alford     New York       0.12  044-25874365
# 8        A009      Benjamin    Hampshair       0.11  008-22536178
# 9        A010    Santakumar      Chennai       0.14  007-22388644
# 10       A011    Ravi Kumar    Bangalore       0.15  077-45625874
# 11       A012        Lucida     San Jose       0.12  044-52981425
# 12       A013  Achmad Malik    Indonesia       0.27     021-14045

# %%
command = "select * from orders"
result.execute(command)
results = result.fetchall()
cols = [column[0] for column in result.description]
results_data= pd.DataFrame.from_records(results, columns = cols)

results_data
# Out:
#    ORD_NUM ORD_AMOUNT ADVANCE_AMOUNT ORD_DATE CUST_CODE AGENT_CODE  \
# 0   200100    1000.00         600.00             C00013       A003
# 1   200101    3000.00        1000.00             C00001       A008
# 2   200102    2000.00         300.00             C00012       A012
# 3   200103    1500.00         700.00             C00021       A005
# 4   200104    1500.00         500.00             C00006       A004
# 5   200105    2500.00         500.00             C00025       A011
# 6   200106    2500.00         700.00             C00005       A002
# 7   200107    4500.00         900.00             C00007       A010
# 8   200108    4000.00         600.00             C00008       A004
# 9   200109    3500.00         800.00             C00011       A010
# 10  200110    3000.00         500.00             C00019       A010
# 11  200111    1000.00         300.00             C00020       A008
# 12  200112    2000.00         400.00             C00016       A007
# 13  200113    4000.00         600.00             C00022       A002
# 14  200114    3500.00        2000.00             C00002       A008
# 15  200116     500.00         100.00             C00010       A009
# 16  200117     800.00         200.00             C00014       A001
# 17  200118     500.00         100.00             C00023       A006
# 18  200119    4000.00         700.00             C00007       A010
# 19  200120     500.00         100.00             C00009       A002
# 20  200121    1500.00         600.00             C00008       A004
# 21  200122    2500.00         400.00             C00003       A004
# 22  200123     500.00         100.00             C00022       A002
# 23  200124     500.00         100.00             C00017       A007
# 24  200125    2000.00         600.00             C00018       A005
# 25  200126     500.00         100.00             C00022       A002
# 26  200127    2500.00         400.00             C00015       A003
# 27  200128    3500.00        1500.00             C00009       A002
# 28  200129    2500.00         500.00             C00024       A006
# 29  200130    2500.00         400.00             C00025       A011
# 30  200131     900.00         150.00             C00012       A012
# 31  200133    1200.00         400.00             C00009       A002
# 32  200134    4200.00        1800.00             C00004       A005
# 33  200135    2000.00         800.00             C00007       A010
#
#    ORD_DESCRIPTION
# 0              SOD
# 1              SOD
# 2              SOD
# 3              SOD
# 4              SOD
# 5              SOD
# 6              SOD
# 7              SOD
# 8              SOD
# 9              SOD
# 10             SOD
# 11             SOD
# 12             SOD
# 13             SOD
# 14             SOD
# 15             SOD
# 16             SOD
# 17             SOD
# 18             SOD
# 19             SOD
# 20             SOD
# 21             SOD
# 22             SOD
# 23             SOD
# 24             SOD
# 25             SOD
# 26             SOD
# 27             SOD
# 28             SOD
# 29             SOD
# 30             SOD
# 31             SOD
# 32             SOD
# 33             SOD

# %%
command = "select * from customer"
result.execute(command)
results = result.fetchall()
cols = [column[0] for column in result.description]
results_data= pd.DataFrame.from_records(results, columns = cols)

results_data
# Out:
#    CUST_CODE    CUST_NAME  CUST_CITY WORKING_AREA CUST_COUNTRY GRADE  \
# 0     C00001      Micheal   New York     New York          USA     2
# 1     C00002         Bolt   New York     New York          USA     3
# 2     C00003       Martin    Torento      Torento       Canada     2
# 3     C00004      Winston    Brisban      Brisban    Australia     1
# 4     C00005     Sasikant     Mumbai       Mumbai        India     1
# 5     C00006      Shilton    Torento      Torento       Canada     1
# 6     C00007   Ramanathan    Chennai      Chennai        India     1
# 7     C00008     Karolina    Torento      Torento       Canada     1
# 8     C00009       Ramesh     Mumbai       Mumbai        India     3
# 9     C00010      Charles  Hampshair    Hampshair           UK     3
# 10    C00011    Sundariya    Chennai      Chennai        India     3
# 11    C00012       Steven   San Jose     San Jose          USA     1
# 12    C00013       Holmes     London       London           UK     2
# 13    C00014   Rangarappa  Bangalore    Bangalore        India     2
# 14    C00015       Stuart     London       London           UK     1
# 15    C00016   Venkatpati  Bangalore    Bangalore        India     2
# 16    C00017     Srinivas  Bangalore    Bangalore        India     2
# 17    C00018      Fleming    Brisban      Brisban    Australia     2
# 18    C00019  Yearannaidu    Chennai      Chennai        India     1
# 19    C00020       Albert   New York     New York          USA     3
# 20    C00021        Jacks    Brisban      Brisban    Australia     1
# 21    C00022      Avinash     Mumbai       Mumbai        India     2
# 22    C00023         Karl     London       London           UK     0
# 23    C00024         Cook     London       London           UK     2
# 24    C00025    Ravindran  Bangalore    Bangalore        India     2
#
#    OPENING_AMT RECEIVE_AMT PAYMENT_AMT OUTSTANDING_AMT      PHONE_NO  \
# 0      3000.00     5000.00     2000.00         6000.00       CCCCCCC
# 1      5000.00     7000.00     9000.00         3000.00       DDNRDRH
# 2      8000.00     7000.00     7000.00         8000.00       MJYURFD
# 3      5000.00     8000.00     7000.00         6000.00       AAAAAAA
# 4      7000.00    11000.00     7000.00        11000.00  147-25896312
# 5     10000.00     7000.00     6000.00        11000.00       DDDDDDD
# 6      7000.00    11000.00     9000.00         9000.00       GHRDWSD
# 7      7000.00     7000.00     9000.00         5000.00       HJKORED
# 8      8000.00     7000.00     3000.00        12000.00      Phone No
# 9      6000.00     4000.00     5000.00         5000.00       MMMMMMM
# 10     7000.00    11000.00     7000.00        11000.00       PPHGRTS
# 11     5000.00     7000.00     9000.00         3000.00       KRFYGJK
# 12     6000.00     5000.00     7000.00         4000.00       BBBBBBB
# 13     8000.00    11000.00     7000.00        12000.00       AAAATGF
# 14     6000.00     8000.00     3000.00        11000.00       GFSGERS
# 15     8000.00    11000.00     7000.00        12000.00       JRTVFDD
# 16     8000.00     4000.00     3000.00         9000.00       AAAAAAB
# 17     7000.00     7000.00     9000.00         5000.00       NHBGVFC
# 18     8000.00     7000.00     7000.00         8000.00       ZZZZBFV
# 19     5000.00     7000.00     6000.00         6000.00       BBBBSBB
# 20     7000.00     7000.00     7000.00         7000.00       WERTGDF
# 21     7000.00    11000.00     9000.00         9000.00  113-12345678
# 22     4000.00     6000.00     7000.00         3000.00       AAAABAA
# 23     4000.00     9000.00     7000.00         6000.00       FSDDSDF
# 24     5000.00     7000.00     4000.00         8000.00       AVAVAVA
#
#    AGENT_CODE
# 0        A008
# 1        A008
# 2        A004
# 3        A005
# 4        A002
# 5        A004
# 6        A010
# 7        A004
# 8        A002
# 9        A009
# 10       A010
# 11       A012
# 12       A003
# 13       A001
# 14       A003
# 15       A007
# 16       A007
# 17       A005
# 18       A010
# 19       A008
# 20       A005
# 21       A002
# 22       A006
# 23       A006
# 24       A011

# %% [markdown]
# ## Contoh : menampilkan sebagian/beberapa kolom pada  tabel Customer.

# %%
command = "SELECT CUST_NAME,CUST_CITY AS 'Kota Asal' FROM customer"
result.execute(command)
results = result.fetchall()
cols = [column[0] for column in result.description]
results_data= pd.DataFrame.from_records(results, columns = cols)

results_data
# Out:
#       CUST_NAME  Kota Asal
# 0       Micheal   New York
# 1          Bolt   New York
# 2        Martin    Torento
# 3       Winston    Brisban
# 4      Sasikant     Mumbai
# 5       Shilton    Torento
# 6    Ramanathan    Chennai
# 7      Karolina    Torento
# 8        Ramesh     Mumbai
# 9       Charles  Hampshair
# 10    Sundariya    Chennai
# 11       Steven   San Jose
# 12       Holmes     London
# 13   Rangarappa  Bangalore
# 14       Stuart     London
# 15   Venkatpati  Bangalore
# 16     Srinivas  Bangalore
# 17      Fleming    Brisban
# 18  Yearannaidu    Chennai
# 19       Albert   New York
# 20        Jacks    Brisban
# 21      Avinash     Mumbai
# 22         Karl     London
# 23         Cook     London
# 24    Ravindran  Bangalore

# %% [markdown]
# # Operasi Update

# %%
command = "SELECT CUST_NAME,GRADE FROM customer"
result.execute(command)
results = result.fetchall()
cols = [column[0] for column in result.description]
results_data= pd.DataFrame.from_records(results, columns = cols)

results_data
# Out:
#       CUST_NAME GRADE
# 0       Micheal     2
# 1          Bolt     3
# 2        Martin     2
# 3       Winston     1
# 4      Sasikant     1
# 5       Shilton     1
# 6    Ramanathan     1
# 7      Karolina     1
# 8        Ramesh     3
# 9       Charles     3
# 10    Sundariya     3
# 11       Steven     1
# 12       Holmes     2
# 13   Rangarappa     2
# 14       Stuart     1
# 15   Venkatpati     2
# 16     Srinivas     2
# 17      Fleming     2
# 18  Yearannaidu     1
# 19       Albert     3
# 20        Jacks     1
# 21      Avinash     2
# 22         Karl     0
# 23         Cook     2
# 24    Ravindran     2

# %%
command = "UPDATE customer SET GRADE = 1 WHERE CUST_NAME = 'Micheal'"
result.execute(command)

# %%
command = "SELECT CUST_NAME,GRADE FROM customer"
result.execute(command)
results = result.fetchall()
cols = [column[0] for column in result.description]
results_data= pd.DataFrame.from_records(results, columns = cols)

results_data
# Out:
#       CUST_NAME GRADE
# 0       Micheal     1
# 1          Bolt     3
# 2        Martin     2
# 3       Winston     1
# 4      Sasikant     1
# 5       Shilton     1
# 6    Ramanathan     1
# 7      Karolina     1
# 8        Ramesh     3
# 9       Charles     3
# 10    Sundariya     3
# 11       Steven     1
# 12       Holmes     2
# 13   Rangarappa     2
# 14       Stuart     1
# 15   Venkatpati     2
# 16     Srinivas     2
# 17      Fleming     2
# 18  Yearannaidu     1
# 19       Albert     3
# 20        Jacks     1
# 21      Avinash     2
# 22         Karl     0
# 23         Cook     2
# 24    Ravindran     2

# %% [markdown]
# # Operasi Delete

# %%
command = "DELETE FROM customer WHERE CUST_NAME = 'Micheal'"
result.execute(command)

# %%
command = "SELECT * FROM customer"
result.execute(command)
results = result.fetchall()
cols = [column[0] for column in result.description]
results_data= pd.DataFrame.from_records(results, columns = cols)

results_data
# Out:
#    CUST_CODE    CUST_NAME  CUST_CITY WORKING_AREA CUST_COUNTRY GRADE  \
# 0     C00002         Bolt   New York     New York          USA     3
# 1     C00003       Martin    Torento      Torento       Canada     2
# 2     C00004      Winston    Brisban      Brisban    Australia     1
# 3     C00005     Sasikant     Mumbai       Mumbai        India     1
# 4     C00006      Shilton    Torento      Torento       Canada     1
# 5     C00007   Ramanathan    Chennai      Chennai        India     1
# 6     C00008     Karolina    Torento      Torento       Canada     1
# 7     C00009       Ramesh     Mumbai       Mumbai        India     3
# 8     C00010      Charles  Hampshair    Hampshair           UK     3
# 9     C00011    Sundariya    Chennai      Chennai        India     3
# 10    C00012       Steven   San Jose     San Jose          USA     1
# 11    C00013       Holmes     London       London           UK     2
# 12    C00014   Rangarappa  Bangalore    Bangalore        India     2
# 13    C00015       Stuart     London       London           UK     1
# 14    C00016   Venkatpati  Bangalore    Bangalore        India     2
# 15    C00017     Srinivas  Bangalore    Bangalore        India     2
# 16    C00018      Fleming    Brisban      Brisban    Australia     2
# 17    C00019  Yearannaidu    Chennai      Chennai        India     1
# 18    C00020       Albert   New York     New York          USA     3
# 19    C00021        Jacks    Brisban      Brisban    Australia     1
# 20    C00022      Avinash     Mumbai       Mumbai        India     2
# 21    C00023         Karl     London       London           UK     0
# 22    C00024         Cook     London       London           UK     2
# 23    C00025    Ravindran  Bangalore    Bangalore        India     2
#
#    OPENING_AMT RECEIVE_AMT PAYMENT_AMT OUTSTANDING_AMT      PHONE_NO  \
# 0      5000.00     7000.00     9000.00         3000.00       DDNRDRH
# 1      8000.00     7000.00     7000.00         8000.00       MJYURFD
# 2      5000.00     8000.00     7000.00         6000.00       AAAAAAA
# 3      7000.00    11000.00     7000.00        11000.00  147-25896312
# 4     10000.00     7000.00     6000.00        11000.00       DDDDDDD
# 5      7000.00    11000.00     9000.00         9000.00       GHRDWSD
# 6      7000.00     7000.00     9000.00         5000.00       HJKORED
# 7      8000.00     7000.00     3000.00        12000.00      Phone No
# 8      6000.00     4000.00     5000.00         5000.00       MMMMMMM
# 9      7000.00    11000.00     7000.00        11000.00       PPHGRTS
# 10     5000.00     7000.00     9000.00         3000.00       KRFYGJK
# 11     6000.00     5000.00     7000.00         4000.00       BBBBBBB
# 12     8000.00    11000.00     7000.00        12000.00       AAAATGF
# 13     6000.00     8000.00     3000.00        11000.00       GFSGERS
# 14     8000.00    11000.00     7000.00        12000.00       JRTVFDD
# 15     8000.00     4000.00     3000.00         9000.00       AAAAAAB
# 16     7000.00     7000.00     9000.00         5000.00       NHBGVFC
# 17     8000.00     7000.00     7000.00         8000.00       ZZZZBFV
# 18     5000.00     7000.00     6000.00         6000.00       BBBBSBB
# 19     7000.00     7000.00     7000.00         7000.00       WERTGDF
# 20     7000.00    11000.00     9000.00         9000.00  113-12345678
# 21     4000.00     6000.00     7000.00         3000.00       AAAABAA
# 22     4000.00     9000.00     7000.00         6000.00       FSDDSDF
# 23     5000.00     7000.00     4000.00         8000.00       AVAVAVA
#
#    AGENT_CODE
# 0        A008
# 1        A004
# 2        A005
# 3        A002
# 4        A004
# 5        A010
# 6        A004
# 7        A002
# 8        A009
# 9        A010
# 10       A012
# 11       A003
# 12       A001
# 13       A003
# 14       A007
# 15       A007
# 16       A005
# 17       A010
# 18       A008
# 19       A005
# 20       A002
# 21       A006
# 22       A006
# 23       A011

# %% [markdown]
# # SELECT dengan Kriteria : NOT NULL

# %%
command = "SELECT * FROM agents WHERE AGENT_CODE IS NOT NULL"
result.execute(command)
results = result.fetchall()
cols = [column[0] for column in result.description]
results_data= pd.DataFrame.from_records(results, columns = cols)

results_data
# Out:
#    AGENT_CODE    AGENT_NAME WORKING_AREA COMMISSION      PHONE_NO COUNTRY
# 0        A001      Subbarao    Bangalore       0.14  077-12346674
# 1        A002        Mukesh       Mumbai       0.11  029-12358964
# 2        A003         Alex        London       0.13  075-12458969
# 3        A004          Ivan      Torento       0.15  008-22544166
# 4        A005      Anderson      Brisban       0.13  045-21447739
# 5        A006         McDen       London       0.15  078-22255588
# 6        A007    Ramasundar    Bangalore       0.15  077-25814763
# 7        A008        Alford     New York       0.12  044-25874365
# 8        A009      Benjamin    Hampshair       0.11  008-22536178
# 9        A010    Santakumar      Chennai       0.14  007-22388644
# 10       A011    Ravi Kumar    Bangalore       0.15  077-45625874
# 11       A012        Lucida     San Jose       0.12  044-52981425
# 12       A013  Achmad Malik    Indonesia       0.27     021-14045

# %% [markdown]
# # SELECT dengan Kriteria : NULL

# %%
command = "SELECT * FROM agents WHERE AGENT_CODE IS NULL"
result.execute(command)
results = result.fetchall()
cols = [column[0] for column in result.description]
results_data= pd.DataFrame.from_records(results, columns = cols)

results_data
# Out:
# Empty DataFrame
# Columns: [AGENT_CODE, AGENT_NAME, WORKING_AREA, COMMISSION, PHONE_NO, COUNTRY]
# Index: []

# %% [markdown]
# Tidak ada data yg muncul karena pada kolom AGENT_CODE tidak ada yg nilainya NULL

# %% [markdown]
# # SELECT dengan Kriteria : Operator Perbandingan

# %%
command = "SELECT * FROM agents WHERE AGENT_CODE='A002';"
result.execute(command)
results = result.fetchall()
cols = [column[0] for column in result.description]
results_data= pd.DataFrame.from_records(results, columns = cols)

results_data
# Out:
#   AGENT_CODE AGENT_NAME WORKING_AREA COMMISSION      PHONE_NO COUNTRY
# 0       A002     Mukesh       Mumbai       0.11  029-12358964

# %% [markdown]
# # SELECT dengan Kriteria : Operator Boolean

# %%
command = "SELECT * FROM orders WHERE ORD_AMOUNT >= 500 AND ADVANCE_AMOUNT >= 300;"
result.execute(command)
results = result.fetchall()
cols = [column[0] for column in result.description]
results_data= pd.DataFrame.from_records(results, columns = cols)

results_data
# Out:
#    ORD_NUM ORD_AMOUNT ADVANCE_AMOUNT ORD_DATE CUST_CODE AGENT_CODE  \
# 0   200100    1000.00         600.00             C00013       A003
# 1   200101    3000.00        1000.00             C00001       A008
# 2   200102    2000.00         300.00             C00012       A012
# 3   200103    1500.00         700.00             C00021       A005
# 4   200104    1500.00         500.00             C00006       A004
# 5   200105    2500.00         500.00             C00025       A011
# 6   200106    2500.00         700.00             C00005       A002
# 7   200107    4500.00         900.00             C00007       A010
# 8   200108    4000.00         600.00             C00008       A004
# 9   200109    3500.00         800.00             C00011       A010
# 10  200110    3000.00         500.00             C00019       A010
# 11  200111    1000.00         300.00             C00020       A008
# 12  200112    2000.00         400.00             C00016       A007
# 13  200113    4000.00         600.00             C00022       A002
# 14  200114    3500.00        2000.00             C00002       A008
# 15  200116     500.00         100.00             C00010       A009
# 16  200117     800.00         200.00             C00014       A001
# 17  200118     500.00         100.00             C00023       A006
# 18  200119    4000.00         700.00             C00007       A010
# 19  200120     500.00         100.00             C00009       A002
# 20  200121    1500.00         600.00             C00008       A004
# 21  200122    2500.00         400.00             C00003       A004
# 22  200123     500.00         100.00             C00022       A002
# 23  200124     500.00         100.00             C00017       A007
# 24  200125    2000.00         600.00             C00018       A005
# 25  200126     500.00         100.00             C00022       A002
# 26  200127    2500.00         400.00             C00015       A003
# 27  200128    3500.00        1500.00             C00009       A002
# 28  200129    2500.00         500.00             C00024       A006
# 29  200130    2500.00         400.00             C00025       A011
# 30  200131     900.00         150.00             C00012       A012
# 31  200133    1200.00         400.00             C00009       A002
# 32  200134    4200.00        1800.00             C00004       A005
# 33  200135    2000.00         800.00             C00007       A010
#
#    ORD_DESCRIPTION
# 0              SOD
# 1              SOD
# 2              SOD
# 3              SOD
# 4              SOD
# 5              SOD
# 6              SOD
# 7              SOD
# 8              SOD
# 9              SOD
# 10             SOD
# 11             SOD
# 12             SOD
# 13             SOD
# 14             SOD
# 15             SOD
# 16             SOD
# 17             SOD
# 18             SOD
# 19             SOD
# 20             SOD
# 21             SOD
# 22             SOD
# 23             SOD
# 24             SOD
# 25             SOD
# 26             SOD
# 27             SOD
# 28             SOD
# 29             SOD
# 30             SOD
# 31             SOD
# 32             SOD
# 33             SOD

# %% [markdown]
# # SELECT dengan Kriteria : Operator LIKE

# %%
command = "SELECT * FROM customer WHERE CUST_NAME LIKE '%S%'"
result.execute(command)
results = result.fetchall()
cols = [column[0] for column in result.description]
results_data= pd.DataFrame.from_records(results, columns = cols)

results_data
# Out:
#    CUST_CODE  CUST_NAME  CUST_CITY WORKING_AREA CUST_COUNTRY GRADE  \
# 0     C00004    Winston    Brisban      Brisban    Australia     1
# 1     C00005   Sasikant     Mumbai       Mumbai        India     1
# 2     C00006    Shilton    Torento      Torento       Canada     1
# 3     C00009     Ramesh     Mumbai       Mumbai        India     3
# 4     C00010    Charles  Hampshair    Hampshair           UK     3
# 5     C00011  Sundariya    Chennai      Chennai        India     3
# 6     C00012     Steven   San Jose     San Jose          USA     1
# 7     C00013     Holmes     London       London           UK     2
# 8     C00015     Stuart     London       London           UK     1
# 9     C00017   Srinivas  Bangalore    Bangalore        India     2
# 10    C00021      Jacks    Brisban      Brisban    Australia     1
# 11    C00022    Avinash     Mumbai       Mumbai        India     2
#
#    OPENING_AMT RECEIVE_AMT PAYMENT_AMT OUTSTANDING_AMT      PHONE_NO  \
# 0      5000.00     8000.00     7000.00         6000.00       AAAAAAA
# 1      7000.00    11000.00     7000.00        11000.00  147-25896312
# 2     10000.00     7000.00     6000.00        11000.00       DDDDDDD
# 3      8000.00     7000.00     3000.00        12000.00      Phone No
# 4      6000.00     4000.00     5000.00         5000.00       MMMMMMM
# 5      7000.00    11000.00     7000.00        11000.00       PPHGRTS
# 6      5000.00     7000.00     9000.00         3000.00       KRFYGJK
# 7      6000.00     5000.00     7000.00         4000.00       BBBBBBB
# 8      6000.00     8000.00     3000.00        11000.00       GFSGERS
# 9      8000.00     4000.00     3000.00         9000.00       AAAAAAB
# 10     7000.00     7000.00     7000.00         7000.00       WERTGDF
# 11     7000.00    11000.00     9000.00         9000.00  113-12345678
#
#    AGENT_CODE
# 0        A005
# 1        A002
# 2        A004
# 3        A002
# 4        A009
# 5        A010
# 6        A012
# 7        A003
# 8        A003
# 9        A007
# 10       A005
# 11       A002

# %% [markdown]
# # SELECT dengan Kriteria : Operator IN dan NOT IN

# %%
command = "SELECT * FROM customer WHERE CUST_COUNTRY IN ('USA','Canada','India');"
result.execute(command)
results = result.fetchall()
cols = [column[0] for column in result.description]
results_data= pd.DataFrame.from_records(results, columns = cols)

results_data
# Out:
#    CUST_CODE    CUST_NAME  CUST_CITY WORKING_AREA CUST_COUNTRY GRADE  \
# 0     C00002         Bolt   New York     New York          USA     3
# 1     C00003       Martin    Torento      Torento       Canada     2
# 2     C00005     Sasikant     Mumbai       Mumbai        India     1
# 3     C00006      Shilton    Torento      Torento       Canada     1
# 4     C00007   Ramanathan    Chennai      Chennai        India     1
# 5     C00008     Karolina    Torento      Torento       Canada     1
# 6     C00009       Ramesh     Mumbai       Mumbai        India     3
# 7     C00011    Sundariya    Chennai      Chennai        India     3
# 8     C00012       Steven   San Jose     San Jose          USA     1
# 9     C00014   Rangarappa  Bangalore    Bangalore        India     2
# 10    C00016   Venkatpati  Bangalore    Bangalore        India     2
# 11    C00017     Srinivas  Bangalore    Bangalore        India     2
# 12    C00019  Yearannaidu    Chennai      Chennai        India     1
# 13    C00020       Albert   New York     New York          USA     3
# 14    C00022      Avinash     Mumbai       Mumbai        India     2
# 15    C00025    Ravindran  Bangalore    Bangalore        India     2
#
#    OPENING_AMT RECEIVE_AMT PAYMENT_AMT OUTSTANDING_AMT      PHONE_NO  \
# 0      5000.00     7000.00     9000.00         3000.00       DDNRDRH
# 1      8000.00     7000.00     7000.00         8000.00       MJYURFD
# 2      7000.00    11000.00     7000.00        11000.00  147-25896312
# 3     10000.00     7000.00     6000.00        11000.00       DDDDDDD
# 4      7000.00    11000.00     9000.00         9000.00       GHRDWSD
# 5      7000.00     7000.00     9000.00         5000.00       HJKORED
# 6      8000.00     7000.00     3000.00        12000.00      Phone No
# 7      7000.00    11000.00     7000.00        11000.00       PPHGRTS
# 8      5000.00     7000.00     9000.00         3000.00       KRFYGJK
# 9      8000.00    11000.00     7000.00        12000.00       AAAATGF
# 10     8000.00    11000.00     7000.00        12000.00       JRTVFDD
# 11     8000.00     4000.00     3000.00         9000.00       AAAAAAB
# 12     8000.00     7000.00     7000.00         8000.00       ZZZZBFV
# 13     5000.00     7000.00     6000.00         6000.00       BBBBSBB
# 14     7000.00    11000.00     9000.00         9000.00  113-12345678
# 15     5000.00     7000.00     4000.00         8000.00       AVAVAVA
#
#    AGENT_CODE
# 0        A008
# 1        A004
# 2        A002
# 3        A004
# 4        A010
# 5        A004
# 6        A002
# 7        A010
# 8        A012
# 9        A001
# 10       A007
# 11       A007
# 12       A010
# 13       A008
# 14       A002
# 15       A011

# %%
command = "SELECT * FROM customer WHERE CUST_COUNTRY NOT IN ('USA','Canada','India');"
result.execute(command)
results = result.fetchall()
cols = [column[0] for column in result.description]
results_data= pd.DataFrame.from_records(results, columns = cols)

results_data
# Out:
#   CUST_CODE CUST_NAME  CUST_CITY WORKING_AREA CUST_COUNTRY GRADE OPENING_AMT  \
# 0    C00004   Winston    Brisban      Brisban    Australia     1     5000.00
# 1    C00010   Charles  Hampshair    Hampshair           UK     3     6000.00
# 2    C00013    Holmes     London       London           UK     2     6000.00
# 3    C00015    Stuart     London       London           UK     1     6000.00
# 4    C00018   Fleming    Brisban      Brisban    Australia     2     7000.00
# 5    C00021     Jacks    Brisban      Brisban    Australia     1     7000.00
# 6    C00023      Karl     London       London           UK     0     4000.00
# 7    C00024      Cook     London       London           UK     2     4000.00
#
#   RECEIVE_AMT PAYMENT_AMT OUTSTANDING_AMT PHONE_NO AGENT_CODE
# 0     8000.00     7000.00         6000.00  AAAAAAA       A005
# 1     4000.00     5000.00         5000.00  MMMMMMM       A009
# 2     5000.00     7000.00         4000.00  BBBBBBB       A003
# 3     8000.00     3000.00        11000.00  GFSGERS       A003
# 4     7000.00     9000.00         5000.00  NHBGVFC       A005
# 5     7000.00     7000.00         7000.00  WERTGDF       A005
# 6     6000.00     7000.00         3000.00  AAAABAA       A006
# 7     9000.00     7000.00         6000.00  FSDDSDF       A006

# %% [markdown]
# # SELECT dengan Kriteria : Operator BETWEEN

# %%
command = "SELECT * FROM orders WHERE ADVANCE_AMOUNT BETWEEN '300' AND '800'"
result.execute(command)
results = result.fetchall()
cols = [column[0] for column in result.description]
results_data= pd.DataFrame.from_records(results, columns = cols)

results_data
# Out:
#    ORD_NUM ORD_AMOUNT ADVANCE_AMOUNT ORD_DATE CUST_CODE AGENT_CODE  \
# 0   200100    1000.00         600.00             C00013       A003
# 1   200102    2000.00         300.00             C00012       A012
# 2   200103    1500.00         700.00             C00021       A005
# 3   200104    1500.00         500.00             C00006       A004
# 4   200105    2500.00         500.00             C00025       A011
# 5   200106    2500.00         700.00             C00005       A002
# 6   200108    4000.00         600.00             C00008       A004
# 7   200110    3000.00         500.00             C00019       A010
# 8   200111    1000.00         300.00             C00020       A008
# 9   200112    2000.00         400.00             C00016       A007
# 10  200113    4000.00         600.00             C00022       A002
# 11  200119    4000.00         700.00             C00007       A010
# 12  200121    1500.00         600.00             C00008       A004
# 13  200122    2500.00         400.00             C00003       A004
# 14  200125    2000.00         600.00             C00018       A005
# 15  200127    2500.00         400.00             C00015       A003
# 16  200129    2500.00         500.00             C00024       A006
# 17  200130    2500.00         400.00             C00025       A011
# 18  200133    1200.00         400.00             C00009       A002
#
#    ORD_DESCRIPTION
# 0              SOD
# 1              SOD
# 2              SOD
# 3              SOD
# 4              SOD
# 5              SOD
# 6              SOD
# 7              SOD
# 8              SOD
# 9              SOD
# 10             SOD
# 11             SOD
# 12             SOD
# 13             SOD
# 14             SOD
# 15             SOD
# 16             SOD
# 17             SOD
# 18             SOD

# %% [markdown]
# # Mengurutkan Data

# %%
command = "SELECT * FROM customer ORDER BY CUST_NAME ASC;"
result.execute(command)
results = result.fetchall()
cols = [column[0] for column in result.description]
results_data= pd.DataFrame.from_records(results, columns = cols)

results_data
# Out:
#    CUST_CODE    CUST_NAME  CUST_CITY WORKING_AREA CUST_COUNTRY GRADE  \
# 0     C00020       Albert   New York     New York          USA     3
# 1     C00022      Avinash     Mumbai       Mumbai        India     2
# 2     C00002         Bolt   New York     New York          USA     3
# 3     C00010      Charles  Hampshair    Hampshair           UK     3
# 4     C00024         Cook     London       London           UK     2
# 5     C00018      Fleming    Brisban      Brisban    Australia     2
# 6     C00013       Holmes     London       London           UK     2
# 7     C00021        Jacks    Brisban      Brisban    Australia     1
# 8     C00023         Karl     London       London           UK     0
# 9     C00008     Karolina    Torento      Torento       Canada     1
# 10    C00003       Martin    Torento      Torento       Canada     2
# 11    C00007   Ramanathan    Chennai      Chennai        India     1
# 12    C00009       Ramesh     Mumbai       Mumbai        India     3
# 13    C00014   Rangarappa  Bangalore    Bangalore        India     2
# 14    C00025    Ravindran  Bangalore    Bangalore        India     2
# 15    C00005     Sasikant     Mumbai       Mumbai        India     1
# 16    C00006      Shilton    Torento      Torento       Canada     1
# 17    C00017     Srinivas  Bangalore    Bangalore        India     2
# 18    C00012       Steven   San Jose     San Jose          USA     1
# 19    C00015       Stuart     London       London           UK     1
# 20    C00011    Sundariya    Chennai      Chennai        India     3
# 21    C00016   Venkatpati  Bangalore    Bangalore        India     2
# 22    C00004      Winston    Brisban      Brisban    Australia     1
# 23    C00019  Yearannaidu    Chennai      Chennai        India     1
#
#    OPENING_AMT RECEIVE_AMT PAYMENT_AMT OUTSTANDING_AMT      PHONE_NO  \
# 0      5000.00     7000.00     6000.00         6000.00       BBBBSBB
# 1      7000.00    11000.00     9000.00         9000.00  113-12345678
# 2      5000.00     7000.00     9000.00         3000.00       DDNRDRH
# 3      6000.00     4000.00     5000.00         5000.00       MMMMMMM
# 4      4000.00     9000.00     7000.00         6000.00       FSDDSDF
# 5      7000.00     7000.00     9000.00         5000.00       NHBGVFC
# 6      6000.00     5000.00     7000.00         4000.00       BBBBBBB
# 7      7000.00     7000.00     7000.00         7000.00       WERTGDF
# 8      4000.00     6000.00     7000.00         3000.00       AAAABAA
# 9      7000.00     7000.00     9000.00         5000.00       HJKORED
# 10     8000.00     7000.00     7000.00         8000.00       MJYURFD
# 11     7000.00    11000.00     9000.00         9000.00       GHRDWSD
# 12     8000.00     7000.00     3000.00        12000.00      Phone No
# 13     8000.00    11000.00     7000.00        12000.00       AAAATGF
# 14     5000.00     7000.00     4000.00         8000.00       AVAVAVA
# 15     7000.00    11000.00     7000.00        11000.00  147-25896312
# 16    10000.00     7000.00     6000.00        11000.00       DDDDDDD
# 17     8000.00     4000.00     3000.00         9000.00       AAAAAAB
# 18     5000.00     7000.00     9000.00         3000.00       KRFYGJK
# 19     6000.00     8000.00     3000.00        11000.00       GFSGERS
# 20     7000.00    11000.00     7000.00        11000.00       PPHGRTS
# 21     8000.00    11000.00     7000.00        12000.00       JRTVFDD
# 22     5000.00     8000.00     7000.00         6000.00       AAAAAAA
# 23     8000.00     7000.00     7000.00         8000.00       ZZZZBFV
#
#    AGENT_CODE
# 0        A008
# 1        A002
# 2        A008
# 3        A009
# 4        A006
# 5        A005
# 6        A003
# 7        A005
# 8        A006
# 9        A004
# 10       A004
# 11       A010
# 12       A002
# 13       A001
# 14       A011
# 15       A002
# 16       A004
# 17       A007
# 18       A012
# 19       A003
# 20       A010
# 21       A007
# 22       A005
# 23       A010

# %% [markdown]
# # Acitivty

# %% [markdown]
# Jawablah pertanyaan-pertanyaan berikut dengan SQL.
# 1. Tampilkan data customer yg mempunyai opening amount diatas 7000.
#
# 2. Tampilkan informasi order yg dilakukan melalui agensi dengan code A003.
#
# 3. Tampilkan data customer yg tinggal di New York, Bangalore, Mumbai, dan Torento.
#
# 4. Tampilkan informasi customer yang mempunyai payment amount diatas 7000 dan urutkan berdasarkan opening amountnya dari yg terbesar
#
# 5. Tampilkan data agensi yang tidak bekerja di london dan memiliki comission lebih dari 0.12

# %% [markdown]
# <br><br><br><br><br>
# 1. Tampilkan data customer yg mempunyai opening amount diatas 7000.

# %%
command = "select * from customer WHERE OPENING_AMT > '7000';"
result.execute(command)
results = result.fetchall()
cols = [column[0] for column in result.description]
results_data= pd.DataFrame.from_records(results, columns = cols)

results_data
# Out:
#    CUST_CODE    CUST_NAME  CUST_CITY WORKING_AREA CUST_COUNTRY GRADE  \
# 0     C00003       Martin    Torento      Torento       Canada     2
# 1     C00005     Sasikant     Mumbai       Mumbai        India     1
# 2     C00007   Ramanathan    Chennai      Chennai        India     1
# 3     C00008     Karolina    Torento      Torento       Canada     1
# 4     C00009       Ramesh     Mumbai       Mumbai        India     3
# 5     C00011    Sundariya    Chennai      Chennai        India     3
# 6     C00014   Rangarappa  Bangalore    Bangalore        India     2
# 7     C00016   Venkatpati  Bangalore    Bangalore        India     2
# 8     C00017     Srinivas  Bangalore    Bangalore        India     2
# 9     C00018      Fleming    Brisban      Brisban    Australia     2
# 10    C00019  Yearannaidu    Chennai      Chennai        India     1
# 11    C00021        Jacks    Brisban      Brisban    Australia     1
# 12    C00022      Avinash     Mumbai       Mumbai        India     2
#
#    OPENING_AMT RECEIVE_AMT PAYMENT_AMT OUTSTANDING_AMT      PHONE_NO  \
# 0      8000.00     7000.00     7000.00         8000.00       MJYURFD
# 1      7000.00    11000.00     7000.00        11000.00  147-25896312
# 2      7000.00    11000.00     9000.00         9000.00       GHRDWSD
# 3      7000.00     7000.00     9000.00         5000.00       HJKORED
# 4      8000.00     7000.00     3000.00        12000.00      Phone No
# 5      7000.00    11000.00     7000.00        11000.00       PPHGRTS
# 6      8000.00    11000.00     7000.00        12000.00       AAAATGF
# 7      8000.00    11000.00     7000.00        12000.00       JRTVFDD
# 8      8000.00     4000.00     3000.00         9000.00       AAAAAAB
# 9      7000.00     7000.00     9000.00         5000.00       NHBGVFC
# 10     8000.00     7000.00     7000.00         8000.00       ZZZZBFV
# 11     7000.00     7000.00     7000.00         7000.00       WERTGDF
# 12     7000.00    11000.00     9000.00         9000.00  113-12345678
#
#    AGENT_CODE
# 0        A004
# 1        A002
# 2        A010
# 3        A004
# 4        A002
# 5        A010
# 6        A001
# 7        A007
# 8        A007
# 9        A005
# 10       A010
# 11       A005
# 12       A002

# %% [markdown]
# <br><br><br><br>
# 2. Tampilkan informasi order yg dilakukan melalui agensi dengan code A003.

# %%
command = "SELECT * FROM orders WHERE AGENT_CODE IN ('A003');"
result.execute(command)
results = result.fetchall()
cols = [column[0] for column in result.description]
results_data= pd.DataFrame.from_records(results, columns = cols)

results_data
# Out:
#   ORD_NUM ORD_AMOUNT ADVANCE_AMOUNT ORD_DATE CUST_CODE AGENT_CODE  \
# 0  200100    1000.00         600.00             C00013       A003
# 1  200127    2500.00         400.00             C00015       A003
#
#   ORD_DESCRIPTION
# 0             SOD
# 1             SOD

# %% [markdown]
# <br><br><br><br>
# 3. Tampilkan data customer yg tinggal di New York, Bangalore, Mumbai, dan Torento.

# %%
command = "SELECT * FROM customer WHERE CUST_CITY IN ('New York', 'banglore','Mumbai','Torento');"
result.execute(command)
results = result.fetchall()
cols = [column[0] for column in result.description]
results_data= pd.DataFrame.from_records(results, columns = cols)

results_data
# Out:
#   CUST_CODE CUST_NAME CUST_CITY WORKING_AREA CUST_COUNTRY GRADE OPENING_AMT  \
# 0    C00002      Bolt  New York     New York          USA     3     5000.00
# 1    C00003    Martin   Torento      Torento       Canada     2     8000.00
# 2    C00005  Sasikant    Mumbai       Mumbai        India     1     7000.00
# 3    C00006   Shilton   Torento      Torento       Canada     1    10000.00
# 4    C00008  Karolina   Torento      Torento       Canada     1     7000.00
# 5    C00009    Ramesh    Mumbai       Mumbai        India     3     8000.00
# 6    C00020    Albert  New York     New York          USA     3     5000.00
# 7    C00022   Avinash    Mumbai       Mumbai        India     2     7000.00
#
#   RECEIVE_AMT PAYMENT_AMT OUTSTANDING_AMT      PHONE_NO AGENT_CODE
# 0     7000.00     9000.00         3000.00       DDNRDRH       A008
# 1     7000.00     7000.00         8000.00       MJYURFD       A004
# 2    11000.00     7000.00        11000.00  147-25896312       A002
# 3     7000.00     6000.00        11000.00       DDDDDDD       A004
# 4     7000.00     9000.00         5000.00       HJKORED       A004
# 5     7000.00     3000.00        12000.00      Phone No       A002
# 6     7000.00     6000.00         6000.00       BBBBSBB       A008
# 7    11000.00     9000.00         9000.00  113-12345678       A002

# %% [markdown]
# <br><br><br><br>
# 4. Tampilkan informasi customer yang mempunyai payment amount diatas 7000 dan urutkan berdasarkan opening amountnya dari yg terbesar

# %%
command = "select * from customer WHERE PAYMENT_AMT > '7000';"
result.execute(command)
results = result.fetchall()
cols = [column[0] for column in result.description]
results_data= pd.DataFrame.from_records(results, columns = cols)

results_data
# Out:
#    CUST_CODE    CUST_NAME  CUST_CITY WORKING_AREA CUST_COUNTRY GRADE  \
# 0     C00002         Bolt   New York     New York          USA     3
# 1     C00003       Martin    Torento      Torento       Canada     2
# 2     C00004      Winston    Brisban      Brisban    Australia     1
# 3     C00005     Sasikant     Mumbai       Mumbai        India     1
# 4     C00007   Ramanathan    Chennai      Chennai        India     1
# 5     C00008     Karolina    Torento      Torento       Canada     1
# 6     C00011    Sundariya    Chennai      Chennai        India     3
# 7     C00012       Steven   San Jose     San Jose          USA     1
# 8     C00013       Holmes     London       London           UK     2
# 9     C00014   Rangarappa  Bangalore    Bangalore        India     2
# 10    C00016   Venkatpati  Bangalore    Bangalore        India     2
# 11    C00018      Fleming    Brisban      Brisban    Australia     2
# 12    C00019  Yearannaidu    Chennai      Chennai        India     1
# 13    C00021        Jacks    Brisban      Brisban    Australia     1
# 14    C00022      Avinash     Mumbai       Mumbai        India     2
# 15    C00023         Karl     London       London           UK     0
# 16    C00024         Cook     London       London           UK     2
#
#    OPENING_AMT RECEIVE_AMT PAYMENT_AMT OUTSTANDING_AMT      PHONE_NO  \
# 0      5000.00     7000.00     9000.00         3000.00       DDNRDRH
# 1      8000.00     7000.00     7000.00         8000.00       MJYURFD
# 2      5000.00     8000.00     7000.00         6000.00       AAAAAAA
# 3      7000.00    11000.00     7000.00        11000.00  147-25896312
# 4      7000.00    11000.00     9000.00         9000.00       GHRDWSD
# 5      7000.00     7000.00     9000.00         5000.00       HJKORED
# 6      7000.00    11000.00     7000.00        11000.00       PPHGRTS
# 7      5000.00     7000.00     9000.00         3000.00       KRFYGJK
# 8      6000.00     5000.00     7000.00         4000.00       BBBBBBB
# 9      8000.00    11000.00     7000.00        12000.00       AAAATGF
# 10     8000.00    11000.00     7000.00        12000.00       JRTVFDD
# 11     7000.00     7000.00     9000.00         5000.00       NHBGVFC
# 12     8000.00     7000.00     7000.00         8000.00       ZZZZBFV
# 13     7000.00     7000.00     7000.00         7000.00       WERTGDF
# 14     7000.00    11000.00     9000.00         9000.00  113-12345678
# 15     4000.00     6000.00     7000.00         3000.00       AAAABAA
# 16     4000.00     9000.00     7000.00         6000.00       FSDDSDF
#
#    AGENT_CODE
# 0        A008
# 1        A004
# 2        A005
# 3        A002
# 4        A010
# 5        A004
# 6        A010
# 7        A012
# 8        A003
# 9        A001
# 10       A007
# 11       A005
# 12       A010
# 13       A005
# 14       A002
# 15       A006
# 16       A006

# %% [markdown]
# <br><br><br>
# 5. Tampilkan data agensi yang tidak bekerja di london dan memiliki comission lebih dari 0.12

# %%
result = connection.cursor()
command = "select * from agents WHERE NOT WORKING_AREA = 'London' AND COMMISSION >= '0.12'"
result.execute(command)
results = result.fetchall()
cols = [column[0] for column in result.description]
results_data= pd.DataFrame.from_records(results, columns = cols)

results_data
# Out:
#   AGENT_CODE    AGENT_NAME WORKING_AREA COMMISSION      PHONE_NO COUNTRY
# 0       A001      Subbarao    Bangalore       0.14  077-12346674
# 1       A004          Ivan      Torento       0.15  008-22544166
# 2       A005      Anderson      Brisban       0.13  045-21447739
# 3       A007    Ramasundar    Bangalore       0.15  077-25814763
# 4       A008        Alford     New York       0.12  044-25874365
# 5       A010    Santakumar      Chennai       0.14  007-22388644
# 6       A011    Ravi Kumar    Bangalore       0.15  077-45625874
# 7       A012        Lucida     San Jose       0.12  044-52981425
# 8       A013  Achmad Malik    Indonesia       0.27     021-14045
